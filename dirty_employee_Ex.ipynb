# %% [markdown]
# <a href="https://colab.research.google.com/github/nikamaishwarya319-cmd/Data-Cleaning-nitflix-Dataset/blob/main/dirty_employee_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dirty-employee.csv")

# %%
print(df.head())
# Out:
#    Employee_ID     Full_Name    Age  Gender Joining_Date  \
# 0          101   Akif Attar    25.0       M     12-02-26
# 1          102      Ali Khan   30.0    Male    20-Mar-25
# 2          103   Sara Sheikh    NaN  Female     12-05-20
# 3          104   Ahmed Patel   -5.0    male    15-Jan-24
# 4          105   Fatima Noor  180.0       F     10-08-23
#
#                Department   Salary      Country           Phone Marks  \
# 0                      IT  ?25,000        India      9876543210    85
# 1  Information Technology  ?30,000  -9876543120      9876543211    90
# 2                    I.T.  ?28,500        INDIA    (987)6543212    88
# 3                      HR  ?35,000          ind    987-654-3213    92
# 4                 Finance  ?40,000       Bharat  +91 9876543214    95
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
print("Shape:",df.shape)
# Out:
# Shape: (20, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Employee_ID   20 non-null     int64
#  1   Full_Name     19 non-null     object
#  2   Age           17 non-null     float64
#  3   Gender        20 non-null     object
#  4   Joining_Date  18 non-null     object
#  5   Department    20 non-null     object
#  6   Salary        20 non-null     object
#  7   Country       20 non-null     object
#  8   Phone         19 non-null     object
#  9   Marks         19 non-null     object
#  10  Unnamed: 10   1 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.8+ KB

# %%
df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# Employee_ID      0
# Full_Name        1
# Age              3
# Gender           0
# Joining_Date     2
# Department       0
# Salary           0
# Country          0
# Phone            1
# Marks            1
# Unnamed: 10     19
# dtype: int64

# %%
df.drop(columns=['Unnamed: 10'],inplace=True)

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
# Out:
# /tmp/ipykernel_5510/1527141296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df['Full_Name'].fillna('Unknown',inplace=True)
# Out:
# /tmp/ipykernel_5510/3225475273.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Full_Name'].fillna('Unknown',inplace=True)

# %%
df['Phone'].fillna('Not Available',inplace=True)
# Out:
# /tmp/ipykernel_5510/3075216670.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Phone'].fillna('Not Available',inplace=True)

# %%
df['Marks'].fillna(df['Marks'].median(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5510/1816101993.py in <cell line: 0>()
# ----> 1 df['Marks'].fillna(df['Marks'].median(),inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in median(self, axis, skipna, numeric_only, **kwargs)
#    6557         **kwargs,
#    6558     ):
# -> 6559         return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#    6560
#    6561     @doc(make_doc("sem", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
df['Full_Name']=df['Full_Name'].str.strip()

# %%
df['Gender']=df['Gender'].str.title().str.strip()

# %%
df['Joining_Date']=pd.to_datetime(df['Joining_Date'],errors='coerce')
# Out:
# /tmp/ipykernel_5510/3010750481.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Joining_Date']=pd.to_datetime(df['Joining_Date'],errors='coerce')

# %%
df=df[(df['Age']>=18)&(df['Age']<=60)]

# %%
df.drop_duplicates(inplace=True)

# %%
df['Salary']=df['Salary'].astype(str).str.replace(',','',regex=False)

# %%
df['Phone']=df['Phone'].astype(str).str.replace(r'\D','',regex=True)

# %%
print("\nNull Values After Cleaning:")
print(df.isnull().sum())
# Out:
# Null Values After Cleaning:
# Employee_ID     0
# Full_Name       0
# Age             0
# Gender          0
# Joining_Date    3
# Department      0
# Salary          0
# Country         0
# Phone           0
# Marks           1
# dtype: int64

# %%
print('\nCleaned Dataset:')
print(df.head())
# Out:
# Cleaned Dataset:
#    Employee_ID    Full_Name   Age  Gender Joining_Date  \
# 0          101   Akif Attar  25.0       M   2026-12-02
# 1          102     Ali Khan  30.0    Male   2025-03-20
# 2          103  Sara Sheikh  27.0  Female   2020-12-05
# 5          106      Unknown  27.0  Female          NaT
# 6          107   John Smith  29.0       M   2022-12-31
#
#                Department  Salary      Country       Phone Marks
# 0                      IT  ?25000        India  9876543210    85
# 1  Information Technology  ?30000  -9876543120  9876543211    90
# 2                    I.T.  ?28500        INDIA  9876543212    88
# 5                      HR  ?27000        India  9876543215    80
# 6                      IT       ?        India  9876543216  1000

# %%
print('\nDataset Shape:')
print(df.shape)
# Out:
# Dataset Shape:
# (17, 10)

# %%
print('\nDataset Information:')
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Employee_ID   17 non-null     int64
#  1   Full_Name     17 non-null     object
#  2   Age           17 non-null     float64
#  3   Gender        17 non-null     object
#  4   Joining_Date  14 non-null     datetime64[ns]
#  5   Department    17 non-null     object
#  6   Salary        17 non-null     object
#  7   Country       17 non-null     object
#  8   Phone         17 non-null     object
#  9   Marks         16 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.5+ KB
# None

# %%
df.to_csv('dirty-employee_cleaned.csv',index=True)
